# %%
import pm4py

# %%
# Asset disbursement to clients - adtc
ocel_file_path = '../dataProcessing/itamSceneMovCombinedOCEL/itam_scene_mov_combined_adtc.jsonocel'
read_ocel = pm4py.read_ocel_json(ocel_file_path)
ocel = pm4py.discover_ocdfg(read_ocel)
pm4py.vis.view_ocdfg(ocel)

# %%
# New asset inventory - nai 
ocel_file_path = '../dataProcessing/itamSceneMovCombinedOCEL/itam_scene_mov_combined_nai.jsonocel'
read_ocel = pm4py.read_ocel_json(ocel_file_path)
ocel = pm4py.discover_ocdfg(read_ocel)
pm4py.vis.view_ocdfg(ocel)

# %%
# Self-service asset check-out - ssaco
ocel_file_path = '../dataProcessing/itamSceneMovCombinedOCEL/itam_scene_mov_combined_ssaco.jsonocel'
read_ocel = pm4py.read_ocel_json(ocel_file_path)
ocel = pm4py.discover_ocdfg(read_ocel)
pm4py.vis.view_ocdfg(ocel)
