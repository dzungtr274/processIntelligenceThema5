# %%
import pm4py

# %%
#Read the input file (all merged ocel logs)
read_file = pm4py.read_ocel_json(f'merged_ocel.jsonocel')

#Discover OCDFG from the log & Visualize
vis_ocel = pm4py.ocel.discover_ocdfg(read_file)
pm4py.vis.view_ocdfg(vis_ocel)
# Out:
# c:\lites\Python38\lib\site-packages\pm4py\util\dt_parsing\parser.py:82: UserWarning: ISO8601 strings are not fully supported with strpfromiso for Python versions below 3.11
#   warnings.warn(
